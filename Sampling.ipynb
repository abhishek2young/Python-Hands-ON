# %% [markdown]
# Sampling
#
# 1. Over Sampling
# 2. Under Sampling
#
# 1. Random Oversampler
# 2. Random UnderSampler
# 3. Smote

# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import RandomOverSampler

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   52        1
# 3                       0.167   21        0
# ...

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
500/(500+268)
# Out:
# 0.6510416666666666

# %%
268/(500+268)
# Out:
# 0.3489583333333333

# %%
x=df.drop("Outcome",axis=1)
y=df["Outcome"]

# %%
x
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   52
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
random_oversampling = RandomOverSampler()
random_oversampling.fit_resample(x,y)
# Out:
# (     Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
#  0        148             50             35        0  33.6
#  1         85             66             29        0  26.6
#  2        183             64              0        0  23.3
#  3        150             66             23       94  28.1
#  4        150             40             35      168  43.1
#  ..       ...            ...            ...      ...   ...
#  995      158            114              0        0  42.3
#  996      138             74             26      144  36.1
#  997      107             62             13       48  22.9
#  998      169             74             19      125  29.9
#  999      173             82             48      465  38.4
#
#       DiabetesPedigreeFunction  Age
#  0                       0.627   50
#  1                       0.351   31
#  2                       0.672   52
#  3                       0.167   21
#  4                       2.288   33
# ...

# %%
x_sampled,y_sampled=random_oversampling.fit_resample(x,y)

# %%
x_sampled
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 995      134             80             37      370  46.2
# 996      138              0              0        0  36.3
# 997      125             78             31        0  27.6
# 998      199             76             43        0  42.9
# 999       92             62              7      258  27.6
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   52
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# ...

# %%
y_sampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Outcome, Length: 1000, dtype: int64

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
random_oversampling = RandomOverSampler(sampling_strategy=0.9)
x_sampled, y_sampled = random_oversampling.fit_resample(x,y)

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    450
# Name: count, dtype: int64

# %% [markdown]
# SMOTE >> Simple minority oversampling technique

# %%
from imblearn.over_sampling import SMOTE

# %%
x
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   52
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
smt = SMOTE(k_neighbors=5)

x_sampled,y_sampled=smt.fit_resample(x,y)
x_sampled
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0        148             50             35        0  33.600000
# 1         85             66             29        0  26.600000
# 2        183             64              0        0  23.300000
# 3        150             66             23       94  28.100000
# 4        150             40             35      168  43.100000
# ..       ...            ...            ...      ...        ...
# 995      184             75             39      283  37.163328
# 996      143             67              0        0  35.731339
# 997      146             62             29      318  31.985346
# 998      165             84             39      322  37.658832
# 999      105             71              0        0  31.018127
#
#      DiabetesPedigreeFunction  Age
# 0                    0.627000   50
# 1                    0.351000   31
# 2                    0.672000   52
# 3                    0.167000   21
# ...

# %%
y_sampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Outcome, Length: 1000, dtype: int64

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
smt = SMOTE(k_neighbors=5,sampling_strategy=0.7)
x_sampled,y_sampled=smt.fit_resample(x,y)
x_sampled
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0        148             50             35        0  33.600000
# 1         85             66             29        0  26.600000
# 2        183             64              0        0  23.300000
# 3        150             66             23       94  28.100000
# 4        150             40             35      168  43.100000
# ..       ...            ...            ...      ...        ...
# 845      152             60             27      318  30.933337
# 846      182             84             10        0  32.921072
# 847      111             73             35      107  30.301612
# 848      135              0              0        0  52.266431
# 849      138             75             26      144  36.139427
#
#      DiabetesPedigreeFunction  Age
# 0                    0.627000   50
# 1                    0.351000   31
# 2                    0.672000   52
# 3                    0.167000   21
# ...

# %%
y_sampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 845    1
# 846    1
# 847    1
# 848    1
# 849    1
# Name: Outcome, Length: 850, dtype: int64

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    350
# Name: count, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
random_undersampling = RandomUnderSampler()
x_sampled,y_sampled=random_undersampling.fit_resample(x,y)
x_sampled
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 249      111             86             19        0  30.1
# 627      132             78              0        0  32.4
# 571      130             96              0        0  22.6
# 304      150             76              0        0  21.0
# 422      102             64             46       78  40.6
# ..       ...            ...            ...      ...   ...
# 755      128             88             39      110  36.5
# 757      123             72              0        0  36.3
# 759      190             92              0        0  35.5
# 761      170             74             31        0  44.0
# 766      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age
# 249                     0.143   23
# 627                     0.393   21
# 571                     0.268   21
# 304                     0.207   37
# 422                     0.496   21
# ..                        ...  ...
# ...

# %%
y_sampled
# Out:
# 249    0
# 627    0
# 571    0
# 304    0
# 422    0
#       ..
# 755    1
# 757    1
# 759    1
# 761    1
# 766    1
# Name: Outcome, Length: 536, dtype: int64

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 0    268
# 1    268
# Name: count, dtype: int64

# %%
random_undersampling = RandomUnderSampler(sampling_strategy=0.80)
random_undersampling.fit_resample(x,y)
x_sampled,y_sampled=random_undersampling.fit_resample(x,y)
y_sampled.value_counts()
# Out:
# Outcome
# 0    335
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# ### Sampling
# 1. Over Sampling
# 2. Under Sampling
#
# 1. Random Oversampler
# 2. Random Undersampler
# 3. SMOTE

# %% [markdown]
# Random OverSampler

# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import RandomOverSampler

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   52        1
# 3                       0.167   21        0
# ...

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
500/(500+268)
# Out:
# 0.6510416666666666

# %%
268/(500+268)
# Out:
# 0.3489583333333333

# %%
x=df.drop("Outcome",axis=1)
y=df["Outcome"]

# %%
random_oversampling = RandomOverSampler()
x_sampled, y_sampled=random_oversampling.fit_resample(x,y,)

# %%
x_sampled
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 995      171             72             33      135  33.3
# 996      144             58             33      135  31.6
# 997      186             90             35      225  34.5
# 998      125             70             18      122  28.9
# 999       80             82             31       70  34.2
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   52
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# ...

# %%
y_sampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Outcome, Length: 1000, dtype: int64

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
random_oversampling = RandomOverSampler(sampling_strategy=0.8)
x_sampled, y_sampled=random_oversampling.fit_resample(x,y)

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    400
# Name: count, dtype: int64

# %%
random_oversampling = RandomOverSampler(sampling_strategy=0.6)
x_sampled, y_sampled=random_oversampling.fit_resample(x,y)

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    300
# Name: count, dtype: int64

# %% [markdown]
# SMOTE >> Synthetic Minority oversampling Technique

# %%
from imblearn.over_sampling import SMOTE

# %%
x
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   52
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
smt = SMOTE(k_neighbors=5)
x_sampled,y_sampled=smt.fit_resample(x,y)
x_sampled
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0        148             50             35        0  33.600000
# 1         85             66             29        0  26.600000
# 2        183             64              0        0  23.300000
# 3        150             66             23       94  28.100000
# 4        150             40             35      168  43.100000
# ..       ...            ...            ...      ...        ...
# 995      142             92             32      145  36.572462
# 996      165              0              0        0  32.016280
# 997      131             67             25      122  31.102648
# 998      160             71             38      116  38.450625
# 999       89             83             27       47  36.326964
#
#      DiabetesPedigreeFunction  Age
# 0                    0.627000   50
# 1                    0.351000   31
# 2                    0.672000   52
# 3                    0.167000   21
# ...

# %%
y_sampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Outcome, Length: 1000, dtype: int64

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
smt =SMOTE(k_neighbors=5,sampling_strategy=0.7)
x_sampled,y_sampled=smt.fit_resample(x,y)
x_sampled
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0        148             50             35        0  33.600000
# 1         85             66             29        0  26.600000
# 2        183             64              0        0  23.300000
# 3        150             66             23       94  28.100000
# 4        150             40             35      168  43.100000
# ..       ...            ...            ...      ...        ...
# 845      131              0              0        0  34.713810
# 846      165             79             44      526  36.916380
# 847      153             44             34      170  39.205642
# 848      136             83             35      130  28.409631
# 849      129             64             29      114  27.458274
#
#      DiabetesPedigreeFunction  Age
# 0                    0.627000   50
# 1                    0.351000   31
# 2                    0.672000   52
# 3                    0.167000   21
# ...

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    350
# Name: count, dtype: int64

# %% [markdown]
# Random Undersampling

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
random_undersampling = RandomUnderSampler()
x_sampled, y_sampled=random_undersampling.fit_resample(x, y)
y_sampled.value_counts()
# Out:
# Outcome
# 0    268
# 1    268
# Name: count, dtype: int64

# %%
random_undersampling = RandomUnderSampler(sampling_strategy=0.7)
x_sampled, y_sampled=random_undersampling.fit_resample(x,y)
y_sampled.value_counts()
# Out:
# Outcome
# 0    382
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# #### Sampling
# 1. OverSampling
# 2. UnderSampling
#
#
# 1. Random Oversampler
# 2. Random UnderSampler
# 3. SMOTE

# %% [markdown]
# Random OverSampler

# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import RandomOverSampler

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   52        1
# 3                       0.167   21        0
# ...

# %%
x=df.drop("Outcome",axis=1)
y=df["Outcome"]

# %%
random_oversampling = RandomOverSampler()
x_sampled, y_sampled=random_oversampling.fit_resample(x, y)
y_sampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
random_oversampling = RandomOverSampler(sampling_strategy=0.8)
x_sampled, y_sampled= random_oversampling.fit_resample(x,y)
y_sampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    400
# Name: count, dtype: int64

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# SMOTE >> Synthetic minority oversampling technique

# %%
from imblearn.over_sampling import SMOTE

# %%
smt =SMOTE()
x_sampled, y_sampled=smt.fit_resample(x,y)
y_sampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
smt =SMOTE(sampling_strategy=0.8)
x_sampled, y_sampled=smt.fit_resample(x,y)
y_sampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    400
# Name: count, dtype: int64

# %% [markdown]
# Ramdom UnderSampling

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
random_undersampling = RandomUnderSampler()
x_sampled,y_sampled = random_undersampling.fit_resample(x,y)
y_sampled.value_counts()
# Out:
# Outcome
# 0    268
# 1    268
# Name: count, dtype: int64

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
random_undersampling = RandomUnderSampler(sampling_strategy=0.9)
x_sampled, y_sampled = random_undersampling.fit_resample(x, y)
y_sampled.value_counts()
# Out:
# Outcome
# 0    297
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# # Sampling

# %% [markdown]
# 1. OverSampling
# 2. UnderSampling
#
# * Random OverSampler
# * Random UnderSampler
# * SMOTE

# %% [markdown]
# Random Oversampler

# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import RandomOverSampler

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   52        1
# 3                       0.167   21        0
# ...

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
x=df.drop("Outcome",axis=1)
y=df["Outcome"]

# %%
x
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   52
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# ...

# %%
random_oversampling = RandomOverSampler()
x_sampled, y_sampled = random_oversampling.fit_resample(x,y)

# %%
x_sampled
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 995      124             74              0        0  34.0
# 996      189            104             25        0  34.3
# 997      164             84             21        0  30.8
# 998      193             70             31        0  34.9
# 999       93             64             32      160  38.0
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   52
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# ...

# %%
x
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   52
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# ...

# %%
y_sampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Outcome, Length: 1000, dtype: int64

# %%
x_sampled.value_counts()
# Out:
# Glucose  BloodPressure  SkinThickness  Insulin  BMI   DiabetesPedigreeFunction  Age
# 152      78             34             171      34.2  0.893                     33     5
# 107      74             0              0        29.6  0.254                     31     5
# 190      92             0              0        35.5  0.278                     66     4
# 148      50             35             0        33.6  0.627                     50     4
# 95       64             0              0        32.0  0.161                     31     4
#                                                                                       ..
# 105      90             0              0        29.6  0.197                     46     1
# 106      52             0              0        31.2  0.380                     42     1
#          54             21             158      30.9  0.292                     24     1
#          56             27             165      29.0  0.426                     22     1
# ...

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
random_oversampling = RandomOverSampler(sampling_strategy=0.9)
x_sampled, y_sampled=random_oversampling.fit_resample(x,y)

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    450
# Name: count, dtype: int64

# %%
random_oversampling=RandomOverSampler(sampling_strategy=0.7)
x_sampled, y_sampled=random_oversampling.fit_resample(x,y)
y_sampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    350
# Name: count, dtype: int64

# %% [markdown]
# SMOTE >> Synthetic minority Oversampling technique

# %%
from imblearn.over_sampling import SMOTE

# %%
x
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   52
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
smt = SMOTE(k_neighbors=5)
x_sampled, y_sampled=smt.fit_resample(x,y)
x_sampled
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0        148             50             35        0  33.600000
# 1         85             66             29        0  26.600000
# 2        183             64              0        0  23.300000
# 3        150             66             23       94  28.100000
# 4        150             40             35      168  43.100000
# ..       ...            ...            ...      ...        ...
# 995      109             75             29        0  32.089558
# 996      176             85             37      490  39.101951
# 997      107             62             17       55  26.638348
# 998      193             78              0        0  23.565381
# 999      163             75              0        0  46.336374
#
#      DiabetesPedigreeFunction  Age
# 0                    0.627000   50
# 1                    0.351000   31
# 2                    0.672000   52
# 3                    0.167000   21
# ...

# %%
y_sampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Outcome, Length: 1000, dtype: int64

# %%
smt =SMOTE(k_neighbors=5,sampling_strategy=0.8)
x_sampled,y_sampled=smt.fit_resample(x,y)
x_sampled
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0        148             50             35        0  33.600000
# 1         85             66             29        0  26.600000
# 2        183             64              0        0  23.300000
# 3        150             66             23       94  28.100000
# 4        150             40             35      168  43.100000
# ..       ...            ...            ...      ...        ...
# 895      178             95             27        0  34.662267
# 896      152             88             29      152  34.912452
# 897      129             70             20      125  31.933684
# 898      143             71             39      248  38.180101
# 899      173             75              0        0  37.293333
#
#      DiabetesPedigreeFunction  Age
# 0                    0.627000   50
# 1                    0.351000   31
# 2                    0.672000   52
# 3                    0.167000   21
# ...

# %%
y_sampled.value_counts()
# Out:
# Outcome
# 0    500
# 1    400
# Name: count, dtype: int64

# %% [markdown]
# Random OverSampling

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
random_undersampling = RandomUnderSampler()
x_sampled, y_sampled=random_undersampling.fit_resample(x, y)
y_sampled.value_counts()
# Out:
# Outcome
# 0    268
# 1    268
# Name: count, dtype: int64

# %%
random_undersampling=RandomUnderSampler(sampling_strategy=0.8)
x_sampled, y_sampled=random_undersampling.fit_resample(x,y)
y_sampled.value_counts()
# Out:
# Outcome
# 0    335
# 1    268
# Name: count, dtype: int64
